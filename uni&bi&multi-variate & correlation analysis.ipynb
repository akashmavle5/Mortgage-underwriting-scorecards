# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#univariate-analysis" data-toc-modified-id="univariate-analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>univariate analysis</a></span><ul class="toc-item"><li><span><a href="#numerical-variables" data-toc-modified-id="numerical-variables-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>numerical variables</a></span></li><li><span><a href="#categorical-variables" data-toc-modified-id="categorical-variables-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>categorical variables</a></span></li></ul></li><li><span><a href="#bivariate-analysis" data-toc-modified-id="bivariate-analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>bivariate analysis</a></span><ul class="toc-item"><li><span><a href="#numeric-variables" data-toc-modified-id="numeric-variables-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>numeric variables</a></span></li><li><span><a href="#categorial-variables" data-toc-modified-id="categorial-variables-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>categorial variables</a></span></li></ul></li><li><span><a href="#multivariate-analysis" data-toc-modified-id="multivariate-analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>multivariate analysis</a></span></li><li><span><a href="#correlation-analysis" data-toc-modified-id="correlation-analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>correlation analysis</a></span><ul class="toc-item"><li><span><a href="#pearson-correlation" data-toc-modified-id="pearson-correlation-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>pearson correlation</a></span></li><li><span><a href="#variable-inflation-factor-(VIF)" data-toc-modified-id="variable-inflation-factor-(VIF)-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>variable inflation factor (VIF)</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

#import os
#if not os.path.exists("figs"): os.makedirs("figs")
#if not os.path.exists("figs/univariate_analysis"): os.makedirs("figs/univariate_analysis")
#if not os.path.exists("figs/bivariate_analysis"): os.makedirs("figs/bivariate_analysis")

# %%
df=pd.read_csv('final_sample_uni.csv')
# Out:
# /Users/jingsixu/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (0,25,28,39,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.shape
# Out:
# (254000, 61)

# %%
df.head(10)
# Out:
#         loan_id  orig_loan_term  fico  ocltv  dti  oltv  x_period  loan_age  \
# 0  100031959830             360   782     80   46    80  09/01/00         1
# 1  100040303714             360   742     90   39    90  06/01/08         2
# 2  100041511703             360   785     80   35    80  12/01/10         0
# 3  100045198012             360   789     71   39    71  09/01/07         3
# 4  100055625380             360   798     80   43    80  09/01/10         0
# 5  100061692731             360   669     80   28    80  09/01/11         2
# 6  100063963595             360   802     39   36    39  06/01/10         1
# 7  100074467951             360   651     71   26    71  12/01/07         1
# 8  100136775358             360   696     72   30    72  12/01/00         2
# 9  100137861518             360   813     75   37    75  09/01/11         1
#
#     cd_msa state  ... change_unem2  pchange_unem curr_unem  Diff_HPI_vol  \
# ...

# %% [markdown]
# <a id="uni"></a>
# ###  univariate analysis

# %% [markdown]
# <a id="uni-nume"></a>
# #### numerical variables

# %%
# numerical variables
continous_cols = ['fico', 'dti', 'ocltv', 'oltv', 'orig_upb', 
                  'rel_median_orig_upb', 'orig_rt', 'sato']

for col in continous_cols:
    print(col)
    print("mean is: ", df[col].mean().round(2))
    print("std is: ", df[col].std().round(2))
    print("min is: ", df[col].min())
    print("max is: ", df[col].max())
    print("1% quantile value is:", df[col].quantile(.01))
    print("10% quantile value is:", df[col].quantile(.1))
    print("90% quantile value is:", df[col].quantile(.9))
    print("99% quantile value is:", df[col].quantile(.99))
    sns.distplot(df[col], label = "univariate analysis on: " + col)
    #plt.savefig("figs/univariate_analysis/" + col + ".png")
    plt.show()
    print()
# Out:
# fico
# mean is:  731.47
# std is:  54.97
# min is:  416
# max is:  850
# 1% quantile value is: 592.0
# 10% quantile value is: 653.0
# 90% quantile value is: 796.0
# 99% quantile value is: 814.0
# dti
# mean is:  34.94
# std is:  11.63
# min is:  1
# max is:  65
# 1% quantile value is: 10.0
# 10% quantile value is: 20.0
# 90% quantile value is: 50.0
# 99% quantile value is: 62.0
# ocltv
# mean is:  74.81
# std is:  16.28
# min is:  6
# max is:  182
# 1% quantile value is: 26.0
# 10% quantile value is: 51.0
# 90% quantile value is: 95.0
# 99% quantile value is: 100.0
# oltv
# mean is:  73.39
# std is:  15.82
# min is:  6
# max is:  104
# 1% quantile value is: 25.0
# 10% quantile value is: 50.0
# 90% quantile value is: 91.0
# 99% quantile value is: 97.0
# orig_upb
# mean is:  186259.68
# std is:  102031.23
# min is:  9000
# max is:  990000
# 1% quantile value is: 41000.0
# 10% quantile value is: 78000.0
# 90% quantile value is: 323000.0
# 99% quantile value is: 506000.0
# ...

# %%
continous_cols_2 = ['fico', 'dti', 'ocltv', 'oltv', 'rel_median_orig_upb']
for col in continous_cols_2:
    plt.boxplot(x = df[col],
                whis = 3,# set extreme ourlier x > Q3+3(Q3-Q1) & X < Q1-3(Q3-Q1)
                patch_artist=True, 
                showmeans=True, # mean: show with point
                boxprops = {'color':'black','facecolor':'#9999ff'}, #set box features
                flierprops = {'marker':'o','markerfacecolor':'red','color':'black'}, # outlier: show with o
                meanprops = {'marker':'D','markerfacecolor':'indianred'}, 
                medianprops = {'linestyle':'--', 'linewidth':2.5, 'color':'orange'}) # medium: show with line
    plt.tick_params(top='off', right='off')
    plt.title("BoxPlot on: " + col )
    plt.show()

# %% [markdown]
# <a id="uni-cate"></a>
# #### categorical variables

# %%
# categorical variables
categorical_columns = ['d90_flag',
                     'num_unit',
                     'cnt_borr',
                     'flag_fthb', 
                     'occpy_sts',
                     'channel',
                     'prop_type',
                     'loan_purpose']


for col in categorical_columns:
    print(col)
    df[col].value_counts().plot(kind = "bar", title = "univariate analysis on: " + col)
    
    for i,v in enumerate(list(df[col].value_counts())):
        plt.text(i+0.035, v, '%d' % v, ha='center', va= 'bottom',fontsize=9)

    #plt.savefig("figs/univariate_analysis/" + col + ".png")
    plt.show() 
    print()
# Out:
# d90_flag
# num_unit
# cnt_borr
# flag_fthb
# occpy_sts
# channel
# prop_type
# loan_purpose

# %% [markdown]
# <a id="bi"></a>
# ### bivariate analysis

# %% [markdown]
# <a id="bi-nume"></a>
# #### numeric variables

# %%
# study relationship of count and continous variables
continous_cols = ['fico', 'dti', 'ocltv', 'oltv', 'orig_upb', 'rel_median_orig_upb', 'orig_rt', 'sato']
for col in continous_cols:
    plt.subplot(111)
    a = df.groupby(pd.qcut(df[col],20,duplicates = 'drop'))[[col, 'd90_flag']].mean()
    plt.plot(a[col],a['d90_flag'])
    
    b = df.groupby([col],as_index=False)[['d90_flag']].mean()
    plt.scatter(b[col],b['d90_flag'],color='orange', s=10)
    #plt.savefig("figs/bivariate_analysis/count_vs_" + col + ".png")
    plt.title("default_rate vs " + col)
    plt.xlabel(col, fontsize =12)
    plt.ylabel('default rate',fontsize =12)
    plt.show()
    #plt.plot(grouped_df.index, grouped_df.values)

# %% [markdown]
# <a id="bi-cate"></a>
# #### categorial variables

# %%
# study relationship of default rate and categorical variables
categorical_columns.remove('d90_flag') 

for col in categorical_columns:
    fig = plt.figure()
    
    ax1 = fig.add_subplot(111)
    d = df[col].value_counts()
    ax1.bar(d.index,d, color = 'grey', width = 0.5)
    ax1.set_ylabel('count')
    
    ax2 = ax1.twinx()
    c = df.groupby([col],as_index=False)[['d90_flag']].mean()
    ax2.plot(c[col],c['d90_flag'],color='red')
    ax2.set_ylim([0, 0.083])
    ax2.set_ylabel('default rate')
    
    plt.title("default_rate vs " + col)
    plt.xlabel(col, fontsize =12)

    plt.show()
    #sns.catplot(x=col, y="d90_flag", data=c, legend = True)
    #plt.savefig("figs/bivariate_analysis/count_vs_" + col + ".png")

# %% [markdown]
# ### multivariate analysis

# %%
pd.pivot_table(df, values = 'd90_flag', aggfunc = 'mean',
               columns = pd.qcut(df['fico'], 4), index = pd.qcut(df['ocltv'], 10,duplicates='drop')).plot(style = '-o')
plt.ylabel('default rate', fontsize=10)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.4), ncol=2, fancybox=True)

# %%
pd.pivot_table(df, values = 'd90_flag', aggfunc = 'count',
               columns = pd.qcut(df['fico'], 4), 
               index = pd.qcut(df['ocltv'], 10,  duplicates='drop'))
# Out:
# fico           (415.999, 693.0]  (693.0, 741.0]  (741.0, 777.0]  \
# ocltv
# (5.999, 51.0]              4220            5014            6480
# (51.0, 63.0]               5343            5572            6771
# (63.0, 70.0]               6492            6097            6536
# (70.0, 75.0]               5888            5862            6382
# (75.0, 80.0]              18478           20624           21571
# (80.0, 90.0]              10873           10025            8853
# (90.0, 95.0]              10728            8349            6516
# (95.0, 182.0]              1896            2171            1364
#
# fico           (777.0, 850.0]
# ocltv
# (5.999, 51.0]           10406
# (51.0, 63.0]             8601
# (63.0, 70.0]             6677
# (70.0, 75.0]             6600
# (75.0, 80.0]            19355
# (80.0, 90.0]             5996
# (90.0, 95.0]             3658
# (95.0, 182.0]             602

# %%
pd.pivot_table(df, values = 'd90_flag', aggfunc = 'mean',
               columns = 'flag_fthb', index = pd.qcut(df['fico'], 20)).plot()
plt.ylabel('default rate', fontsize=10)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.3), ncol=2, fancybox=True)

# %%
pd.pivot_table(df, values = 'd90_flag', aggfunc = 'mean',
               columns = 'prop_type', index = pd.qcut(df['fico'], 20)).plot()
plt.ylabel('default rate', fontsize=10)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.3), ncol=2, fancybox=True)

# %%
pd.pivot_table(df, values = 'd90_flag', aggfunc = 'mean',
               columns = 'loan_purpose', index = pd.qcut(df['fico'], 20)).plot()
plt.ylabel('default rate', fontsize=10)
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.3), ncol=2, fancybox=True)

# %% [markdown]
# Since among different categories, the trends against default rate are very similar to each other, there is no need for adding interaction terms.

# %% [markdown]
# <a id="corr"></a>
# ### correlation analysis

# %% [markdown]
# #### pearson correlation

# %%
# drop non-numerical variables
continous_cols = ['fico', 'dti', 'ocltv', 'oltv', 'orig_upb', 
                  'rel_median_orig_upb', 'orig_rt', 'sato']

# calculate and plot
corr_matrix = df[continous_cols ].corr()
sns.heatmap(corr_matrix)

# %%
corr_matrix
# Out:
#                          fico       dti     ocltv      oltv  orig_upb  \
# fico                 1.000000 -0.164040 -0.170390 -0.182904  0.134446
# dti                 -0.164040  1.000000  0.111409  0.106878  0.080707
# ocltv               -0.170390  0.111409  1.000000  0.954669 -0.000506
# oltv                -0.182904  0.106878  0.954669  1.000000 -0.031804
# orig_upb             0.134446  0.080707 -0.000506 -0.031804  1.000000
# rel_median_orig_upb  0.039276  0.056918  0.147086  0.117636  0.796115
# orig_rt             -0.324011  0.082970  0.156600  0.172013 -0.318349
# sato                -0.160222  0.063887  0.115623  0.136641 -0.156510
#
#                      rel_median_orig_upb   orig_rt      sato
# fico                            0.039276 -0.324011 -0.160222
# dti                             0.056918  0.082970  0.063887
# ocltv                           0.147086  0.156600  0.115623
# oltv                            0.117636  0.172013  0.136641
# ...

# %%
for row in range(corr_matrix.shape[0]):
    for col in range(corr_matrix.shape[1]):
        value = corr_matrix.iat[row, col]
        if abs(value) > 0.2 and row < col:
            print(corr_matrix.index[row], corr_matrix.columns[col], round(value,4))
# Out:
# fico orig_rt -0.324
# ocltv oltv 0.9547
# orig_upb rel_median_orig_upb 0.7961
# orig_upb orig_rt -0.3183
# orig_rt sato 0.3664

# %% [markdown]
# Therefore, we removed 'oltv', 'orig_upb', 'orig_rt' and would only use 'fico', 'dti', 'ocltv', 'rel_median_orig_upb', 'sato'

# %% [markdown]
# #### variable inflation factor (VIF)

# %% [markdown]
# check multicollinearity

# %%
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
X = df[continous_cols]

# %%
calc_vif(X)
# Out:
#              variables         VIF
# 0                 fico   43.665886
# 1                  dti   10.088176
# 2                ocltv  253.404646
# 3                 oltv  257.100722
# 4             orig_upb   14.646687
# 5  rel_median_orig_upb   18.597403
# 6              orig_rt   38.136832
# 7                 sato    1.253573

# %%
X_fix = df[['fico', 'dti', 'ocltv', 'rel_median_orig_upb', 'sato']]

# %%
calc_vif(X_fix)
# Out:
#              variables        VIF
# 0                 fico  23.205958
# 1                  dti   9.552738
# 2                ocltv  20.210819
# 3  rel_median_orig_upb   6.154967
# 4                 sato   1.098425

# %%
df.groupby(pd.qcut(df['fico'],100,duplicates = 'drop'))[ 'ocltv'].mean().plot(style = "-o")

# %% [markdown]
# From previous analysis, 'fico' and 'ocltv' have low correlation but has relatively high multicolinearity with other factors. This increases the risk of model overfitting. However, since we have over 250,000 observations, the risk of overfitting is not high, and both 'fico' and 'ocltv' are highly used in industry, we will keep there features.
